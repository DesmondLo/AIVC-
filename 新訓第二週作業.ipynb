# %% [markdown]
# <a href="https://colab.research.google.com/github/DesmondLo/AIVC-/blob/main/%E6%96%B0%E8%A8%93%E7%AC%AC%E4%BA%8C%E9%80%B1%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 說明

# %% [markdown]
# 1.   請使用Numpy完成程式碼，禁止額外套用套件，可以使用cv2_imread
# 2.   可以使用自己完成的副程式
# 3.   完成程式碼後，請與cv2的結果做對比
# 4.   輸出圖片與cv2的結果需要一致

# %% [markdown]
# # 引入套件

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# 圖片來源 https://upload.wikimedia.org/wikipedia/zh/3/34/Lenna.jpg

# %% [markdown]
# # 顯示原圖片

# %%
# Opencv結果
# !wget https://upload.wikimedia.org/wikipedia/zh/3/34/Lenna.jpg -O lena.jpg
img = cv2.imread('lena.jpg')
img_g = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # 彩色轉灰階
cv2_imshow(img) # 顯示圖片
cv2_imshow(img_g)
# Out:
# --2026-02-22 10:15:04--  https://upload.wikimedia.org/wikipedia/zh/3/34/Lenna.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 160012 (156K) [image/jpeg]
# Saving to: ‘lena.jpg’
#
# lena.jpg            100%[===================>] 156.26K  --.-KB/s    in 0.06s
#
# 2026-02-22 10:15:04 (2.35 MB/s) - ‘lena.jpg’ saved [160012/160012]
# <PIL.Image.Image image mode=RGB size=316x316>
# <PIL.Image.Image image mode=L size=316x316>

# %% [markdown]
# # 二值化 binarize

# %% [markdown]
# ## 說明

# %% [markdown]
# 二值化是將圖像轉換成只有兩種像素值的過程，通常是黑色(0)和白色（255）。這通常是通過設置一個閾值來實現的，高於閾值的像素設置為一個值，低於閾值的像素設置為另一個值。

# %% [markdown]
# 二值化常用於從圖像中分離出前景和背景，尤其是在文字識別、條形碼識別和其他需要分辨物體輪廓的應用中。

# %% [markdown]
# [連結文字](https://www.google.com/url?sa=i&url=https%3A%2F%2Fhackmd.io%2F%40Youwe%2FSkBHZmcrI&psig=AOvVaw0gepMQc5qRlv9XhV0K7Ojg&ust=1706693413559000&source=images&cd=vfe&opi=89978449&ved=0CBIQjRxqFwoTCKjI_8bmhIQDFQAAAAAdAAAAABAE)

# %% [markdown]
# ## 代碼

# %%
# Opencv結果
rer, img_b = cv2.threshold(img_g, 50, 255, cv2.THRESH_BINARY)
cv2_imshow(img_b)
# Out:
# <PIL.Image.Image image mode=L size=316x316>

# %%
def binarize(img,thresh,maxval):
  mask = (img > thresh)
  out = np.zeros_like(img)
  out[mask] = maxval
  return out # 回傳圖片

result = binarize(img_g, 50, 255)
cv2_imshow(result)
print("二值化結果", np.array_equal(result, img_b))
# Out:
# <PIL.Image.Image image mode=L size=316x316>
# 二值化結果 True

# %% [markdown]
# # 大津演算法 OTSU

# %% [markdown]
# ## 說明

# %% [markdown]
# 在大津演算法中，我們的目標是找到一個最適合的閾值，以便將影像的像素分成前景和背景兩個類別。

# %% [markdown]
# 以下是大津演算法中用來計算類間變異數的公式及一些名詞解釋。

# %% [markdown]
# ![clipboard-image-1706682808.png](data:image/png;base64,...)

# %% [markdown]
# 演算法的步驟如下：
# 1. 計算每個灰階值的直方圖並計算出現的 PMF 機率質量函數 H(X=xi)。
# 2. 初始化變數 w1(0) 和 μ1(0)。
# 3. 遍歷閾值 t 從 0 到 255 的範圍：
#   1. 計算參數 w1(t)、μ1(t)、w2(t)、μ2(t)。
#   2. 計算類間變異數 σb(t)。
#   3. 如果目前的類間變異數大於先前的最大值，更新最大值。
#   4. 記錄當前的閾值 t。
# 4. 最終，使用記錄的閾值找到最大類間變異數對應的閾值。

# %% [markdown]
# 大津演算法在二值化影像、圖像分割等領域有廣泛應用，因為它能夠自動選擇
# 適當的閾值，而不需要人為調整。

# %% [markdown]
# ## 代碼

# %%
# Opencv結果
ret, img_o = cv2.threshold(img_g, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
print(ret)
cv2_imshow(img_o)
# Out:
# 117.0
# <PIL.Image.Image image mode=L size=316x316>

# %%
def otsu(img_gray):
  # TODO 待完成程式碼，只允許使用numpy或是自己寫的副程式
  pmf = PMF(img_gray)

  th = 0
  max_sigma_b2 = -1
  for t in range(256):
    w1 = pmf[:t+1].sum()
    w2 = pmf[t+1:].sum()
    if w1 == 0 or w2 == 0:
      continue
    class1 = np.arange(0, t+1)
    class2 = np.arange(t+1, 256)

    u1 = (class1*pmf[:t+1]).sum() / w1
    u2 = (class2*pmf[t+1:]).sum() / w2

    sigma_b2 = w1* w2 * (u1-u2) ** 2
    if sigma_b2 > max_sigma_b2:
      max_sigma_b2 = sigma_b2
      th = t

  return th # 回傳閾值
def PMF(img):
  img = img.astype(np.uint8)
  img_r = img.ravel()
  hist = np.bincount(img_r, minlength=256)
  pmf = hist / hist.sum()
  return pmf

ret = otsu(img_g) # 使用設計的otsu副程式，得到閾值
result = binarize(img_g, ret, 255) # 使用剛剛完成的二值化副程式

cv2_imshow(result)
print("otsu結果", np.array_equal(result, img_o))
# Out:
# <PIL.Image.Image image mode=L size=316x316>
# otsu結果 True

# %% [markdown]
# # 腐蝕 Erode

# %% [markdown]
# ## 說明

# %% [markdown]
# 腐蝕是一種侵蝕圖像前景的操作，它會移除圖像邊緣的像素。這是通過將一個結構元素滑動過圖像，並只保留結構元素完全覆蓋前景的區域來實現的。

# %% [markdown]
# 腐蝕用於去除小的噪點，分離相鄰的物體，並縮小物體的大小。這在處理不規則形狀或消除小於某個大小的物體時非常有用。

# %% [markdown]
# [連結文字](https://www.google.com/url?sa=i&url=https%3A%2F%2Fshengyu7697.github.io%2Fpython-opencv-erode-dilate%2F&psig=AOvVaw29YmyilbAS0RFCKQpbipo8&ust=1706693534273000&source=images&cd=vfe&opi=89978449&ved=0CBIQjRxqFwoTCIjluoDnhIQDFQAAAAAdAAAAABAE)

# %% [markdown]
# ## 代碼

# %%
# Opencv結果
kernel = np.ones((3,3))
img_e = cv2.erode(img_o, kernel, iterations = 2)
cv2_imshow(img_e)
# Out:
# <PIL.Image.Image image mode=L size=316x316>

# %%
def _erode_single_iteration(img, kernel):
    h, w = img.shape
    kh, kw = kernel.shape
    pad_h = kh // 2
    pad_w = kw // 2

    # 邊界補償用reflect edge都可
    padded = np.pad(img, ((pad_h, pad_h), (pad_w, pad_w)), mode='reflect')

    out = np.zeros_like(img, dtype=np.uint8)

    for i in range(h):
        for j in range(w):
            region = padded[i:i+kh, j:j+kw]
            # 腐蝕邏輯：如果卷積核覆蓋區域內的所有前景像素 (255) 都是 255，則輸出像素為 255
            # 這裡假設 kernel 是 np.ones((3,3))，所以檢查 region 內所有元素
            if np.all(region == 255):
                out[i, j] = 255
            else:
                out[i, j] = 0
    return out

def erode(img,kernel=np.ones((3,3), dtype=np.uint8),iterations=1):
  current_img = img.copy()
  for _ in range(iterations):
    current_img = _erode_single_iteration(current_img, kernel)
  return current_img # 輸出圖片
result = erode(img_o, kernel, iterations = 2) # 使用設計的腐蝕副程式，得到腐蝕後的圖片
cv2_imshow(result)
print("腐蝕結果", np.array_equal(result, img_e))
# Out:
# <PIL.Image.Image image mode=L size=316x316>
# 腐蝕結果 True

# %% [markdown]
# # 膨脹 Dilate

# %% [markdown]
# ## 說明

# %% [markdown]
# 膨脹是與腐蝕相反的操作，它會增加圖像前景的像素。這是通過將一個結構元素滑動過圖像，並將結構元素接觸到的所有背景轉換為前景來實現的。

# %% [markdown]
# 膨脹用於填充前景物體中的小洞，連接靠近的物體，並增加物體的大小。這在強調特定特徵或閉合小的間隙時很有幫助。

# %% [markdown]
# ## 代碼

# %%
# Opencv結果
kernel = np.ones((3,3))
img_d = cv2.dilate(img_o, kernel, iterations = 2)
cv2_imshow(img_d)
# Out:
# <PIL.Image.Image image mode=L size=316x316>

# %%
def _dilate_single_iteration(img, kernel):
    h, w = img.shape
    kh, kw = kernel.shape
    pad_h = kh // 2
    pad_w = kw // 2

    padded = np.pad(img, ((pad_h, pad_h), (pad_w, pad_w)), mode='reflect')

    # 輸出影像應為 np.uint8 類型
    out = np.zeros_like(img, dtype=np.uint8)

    for i in range(h):
        for j in range(w):
            region = padded[i:i+kh, j:j+kw]
            # 膨脹邏輯：如果卷積核覆蓋區域內有任何前景像素 (255)，則輸出像素為 255
            if np.any(region == 255):
                out[i, j] = 255
            else:
                out[i, j] = 0
    return out

def dilate(img,kernel=np.ones((3,3), dtype=np.uint8),iterations=1):
  current_img = img.copy()
  for _ in range(iterations):
    current_img = _dilate_single_iteration(current_img, kernel)
  return current_img # 輸出圖片

result = dilate(img_o, kernel, iterations = 2) # 使用設計的膨脹副程式，得到膨脹後的圖片
cv2_imshow(result)
print("膨脹結果", np.array_equal(result, img_d))
# Out:
# <PIL.Image.Image image mode=L size=316x316>
# 膨脹結果 True

# %% [markdown]
# # 開運算 Open

# %% [markdown]
# ## 說明

# %% [markdown]
# 開運算是由一個腐蝕（Erosion）操作後接著一個膨脹（Dilation）操作組成的序列。
#
# 開運算可以用來去除二值化影像中的小物體，填充物體內的小洞。
#
# 開運算的效果是平滑物體邊界，同時保持物體的整體形狀。

# %% [markdown]
# ## 代碼

# %%
# Opencv結果
kernel = np.ones((3,3))
img_open = cv2.morphologyEx(img_o, cv2.MORPH_OPEN, kernel)
cv2_imshow(img_open)
# Out:
# <PIL.Image.Image image mode=L size=316x316>

# %%
def open(img, kernel):
  # TODO 待完成程式碼，只允許使用numpy或是自己寫的副程式
  # 開運算==>先腐蝕再膨脹
  eroded_img = erode(img, kernel, iterations=1)
  out = dilate(eroded_img, kernel, iterations=1)
  return out

result = open(img_o, kernel) # 使用設計的開運算副程式，得到開運算後的圖片
cv2_imshow(result)
print("開運算結果", np.array_equal(result, img_open))
# Out:
# <PIL.Image.Image image mode=L size=316x316>
# 開運算結果 True

# %% [markdown]
# # 閉運算 Close

# %% [markdown]
# ## 說明

# %% [markdown]
# 閉運算是由一個膨脹（Dilation）操作後接著一個腐蝕（Erosion）操作組成的序列。
#
# 閉運算可以用來填充二值化影像中的小孔，平滑物體內部的細小細節。
#
# 閉運算的效果是平滑物體的表面，同時保持物體的整體形狀。

# %% [markdown]
# ## 代碼

# %%
# Opencv結果
kernel = np.ones((3,3))
img_close = cv2.morphologyEx(img_o, cv2.MORPH_CLOSE, kernel)
cv2_imshow(img_close)
# Out:
# <PIL.Image.Image image mode=L size=316x316>

# %%
def close(img, kernel):
  # TODO 待完成程式碼，只允許使用numpy或是自己寫的副程式
  # 閉運算==>先膨脹再腐蝕
  dilate_img = dilate(img, kernel, iterations=1)
  out = erode(dilate_img, kernel, iterations=1)
  return out

result = close(img_o, kernel) # 使用設計的閉運算副程式，得到閉運算後的圖片
cv2_imshow(result)
print("閉運算結果", np.array_equal(result, img_close))
# Out:
# <PIL.Image.Image image mode=L size=316x316>
# 閉運算結果 True

# %% [markdown]
# # 所有輸出都為True後，請上傳到群組中
